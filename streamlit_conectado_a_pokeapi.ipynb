# %% [markdown]
# # Streamlit conectado al proyecto de PokéAPI
#
# ## Objetivo
# Este notebook explica cómo conectar el trabajo del notebook de PokéAPI con un dashboard en **Streamlit**.
#
# ## Qué aprenderás
# - Qué es Streamlit
# - Cómo instalarlo
# - Cómo crear un archivo `app.py`
# - Cómo conectar el dashboard con una API o con datos procesados
# - Cómo ejecutar el dashboard
#
# ## Flujo del proyecto
#
# ```text
# PokéAPI → requests → pandas → FastAPI / función Python → Streamlit
# ```

# %% [markdown]
# ## 1. ¿Qué es Streamlit?
#
# **Streamlit** es una librería de Python para crear dashboards y aplicaciones web de forma rápida.
#
# Con Streamlit puedes:
# - mostrar tablas
# - mostrar métricas
# - hacer gráficos
# - añadir filtros
# - crear una pequeña app sin usar HTML, CSS o JavaScript

# %% [markdown]
# ## 2. Instalar Streamlit
#
# Ejecuta este comando en la terminal o en una celda del notebook.

# %%
# !pip install streamlit

# %% [markdown]
# ## 3. Idea de conexión con el notebook anterior
#
# En el notebook anterior ya aprendiste a:
# - conectarte a PokéAPI
# - transformar JSON en DataFrame
# - crear una función `get_pokemon_data(limit=5)`
#
# Ahora usaremos esa misma lógica para construir un dashboard en Streamlit.

# %% [markdown]
# ## 4. Opción A: Streamlit usando la misma función Python
#
# Esta es la forma más simple.
# Creamos un archivo `app.py` y dentro ponemos una función para cargar los datos.

# %%
streamlit_code = '''
import streamlit as st
import requests
import pandas as pd

BASE_URL = "https://pokeapi.co/api/v2/pokemon"

@st.cache_data
def get_pokemon_data(limit=10):
    response = requests.get(f"{BASE_URL}?limit={limit}")
    data = response.json()
    results = []

    for pokemon in data["results"]:
        poke_response = requests.get(pokemon["url"])
        if poke_response.status_code == 200:
            poke_data = poke_response.json()
            results.append({
                "name": poke_data["name"],
                "height": poke_data["height"],
                "weight": poke_data["weight"],
                "base_experience": poke_data["base_experience"]
            })

    return pd.DataFrame(results)

st.title("Dashboard Pokémon con Streamlit")

limit = st.slider("Número de Pokémon", min_value=5, max_value=30, value=10)

df = get_pokemon_data(limit)

col1, col2, col3 = st.columns(3)
col1.metric("Total Pokémon", len(df))
col2.metric("Peso medio", round(df["weight"].mean(), 2))
col3.metric("Altura media", round(df["height"].mean(), 2))

st.subheader("Tabla de datos")
st.dataframe(df)

st.subheader("Top experiencia base")
top_df = df.sort_values("base_experience", ascending=False)
st.bar_chart(top_df.set_index("name")["base_experience"])

st.subheader("Peso por Pokémon")
st.bar_chart(df.set_index("name")["weight"])
'''

print(streamlit_code)

# %% [markdown]
# ## 5. Guardar el archivo `app.py`
#
# Con esta celda puedes crear automáticamente el archivo del dashboard.

# %%
with open("app.py", "w", encoding="utf-8") as f:
    f.write(streamlit_code)

print("Archivo app.py creado correctamente")

# %% [markdown]
# ## 6. Ejecutar Streamlit
#
# Una vez creado `app.py`, abre una terminal y ejecuta:
#
# ```bash
# streamlit run app.py
# ```
#
# La aplicación normalmente se abrirá en:
#
# ```
# http://localhost:8501
# ```

# %% [markdown]
# ## 7. Relación entre notebooks
#
# Puedes usar este notebook junto al anterior así:
#
# ### Notebook 1
# Explica:
# - requests
# - JSON
# - pandas
# - extracción de datos
#
# ### Notebook 2 (este)
# Explica:
# - cómo convertir esos datos en una app visual con Streamlit
# - cómo pasar de análisis a dashboard

# %% [markdown]
# ## 8. Conclusión
#
# Con Streamlit puedes convertir tu trabajo de análisis y consumo de API en una aplicación visual.
#
# Eso hace que tu proyecto pase de:
#
# ```
# Notebook técnico
# ```
#
# a:
#
# ```
# Proyecto visual + portfolio
# ```
